# %%
import os
from pathlib import Path

# Check if the current working directory is 'notebooks'
if Path.cwd().name == "notebooks":
    # Change the current working directory to the parent directory
    os.chdir("..")

# %%
from kalshi_tracker import kalshi

api = kalshi.get_kalshi()

# %%
api.get_exchange_status()
# Out:
# {'exchange_active': True, 'trading_active': True}

# %%
help(api.portfolio_api)
# Out:
# Help on PortfolioApi in module kalshi_python.api.portfolio_api object:
#
# class PortfolioApi(builtins.object)
#  |  PortfolioApi(api_client=None)
#  |
#  |  NOTE: This class is auto generated by the swagger code generator program.
#  |
#  |  Do not edit the class manually.
#  |  Ref: https://github.com/swagger-api/swagger-codegen
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, api_client=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  batch_cancel_orders(self, body, **kwargs)
#  |      BatchCancelOrders  # noqa: E501
#  |
#  |      Endpoint for cancelling up to 20 orders at once. Available to members with advanced access only.  # noqa: E501
#  |      This method makes a synchronous HTTP request by default. To make an
#  |      asynchronous HTTP request, please pass async_req=True
#  |      >>> thread = api.batch_cancel_orders(body, async_req=True)
#  |      >>> result = thread.get()
#  |
#  |      :param async_req bool
# ...

# %%
help(api)
# Out:
# Help on ApiInstance in module kalshi_python.api_instance object:
#
# class ApiInstance(builtins.object)
#  |  ApiInstance(email=None, password=None, configuration=None, header_name=None, header_value=None, cookie=None)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, email=None, password=None, configuration=None, header_name=None, header_value=None, cookie=None)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  auto_login_if_possible(self)
#  |
#  |  batch_cancel_orders(self, body, **kwargs)
#  |      # Proxy portfolio methods
#  |
#  |  batch_create_orders(self, body, **kwargs)
#  |
#  |  cancel_order(self, order_id, **kwargs)
#  |
#  |  create_order(self, body, **kwargs)
#  |
#  |  decrease_order(self, body, order_id, **kwargs)
#  |
#  |  get_balance(self, **kwargs)
#  |
#  |  get_event(self, event_ticker, **kwargs)
#  |      # Proxy market methods
#  |
#  |  get_events(self, **kwargs)
#  |
#  |  get_exchange_status(self, **kwargs)
# ...

# %%
import pandas as pd

# %%
markets = api.market_api.get_markets()
# Out:
# ---------------------------------------------------------------------------
# ApiException                              Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 markets = api.market_api.get_markets()
#
# File ~/personal/prediction_market_tools/.venv/lib/python3.11/site-packages/kalshi_python/api/market_api.py:564, in MarketApi.get_markets(self, **kwargs)
#     562     return self.get_markets_with_http_info(**kwargs)  # noqa: E501
#     563 else:
# --> 564     (data) = self.get_markets_with_http_info(**kwargs)  # noqa: E501
#     565     return data
#
# File ~/personal/prediction_market_tools/.venv/lib/python3.11/site-packages/kalshi_python/api/market_api.py:641, in MarketApi.get_markets_with_http_info(self, **kwargs)
#     638 # Authentication setting
#     639 auth_settings = ['bearer_token']  # noqa: E501
# --> 641 return self.api_client.call_api(
#     642     '/markets', 'GET',
#     643     path_params,
#     644     query_params,
# ...

# %%
import pprint

# %%
pprint.pp(markets)

# %%
api.get_events()

# %%
pd.DataFrame()
