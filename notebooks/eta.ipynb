# %%
import os
from pathlib import Path

# Check if the current working directory is 'notebooks'
if Path.cwd().name == "notebooks":
    # Change the current working directory to the parent directory
    os.chdir("..")

# %%
from src.config import Settings

settings = Settings()

# %%
from src import kalshi

api = kalshi.get_kalshi(settings.kalshi)

# %%
import pandas as pd

# %%
markets = api.get_markets()

# %%
import pprint

# %%
pprint.pp(markets)
# Out:
# {'cursor': 'CgsIpdOjuAYQ8O_2CRIYTkFTREFRMTAwLTI0T0NUMTgtQjIwNjUw',
#  'markets': [{'can_close_early': True,
#               'cap_strike': None,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T04:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHAUS-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 100,
#               'last_price': 0,
#               'liquidity': 25557,
#               'no_ask': 99,
#               'no_bid': 86,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'greater',
#               'subtitle': '101° or above',
#               'ticker': 'HIGHAUS-24OCT13-T100',
#               'title': 'Will the **high temp in Austin** be >100° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 14,
#               'yes_bid': 1},
#              {'can_close_early': True,
#               'cap_strike': 100,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T04:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHAUS-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 99,
#               'last_price': 36,
#               'liquidity': 53076,
#               'no_ask': 64,
#               'no_bid': 57,
#               'open_interest': 49,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '99° to 100°',
#               'ticker': 'HIGHAUS-24OCT13-B99.5',
#               'title': 'Will the **high temp in Austin** be 99-100° on Oct 13, '
#                        '2024?',
#               'volume': 49,
#               'volume_24h': 49,
#               'yes_ask': 43,
#               'yes_bid': 36},
#              {'can_close_early': True,
#               'cap_strike': 98,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T04:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHAUS-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 97,
#               'last_price': 0,
#               'liquidity': 72186,
#               'no_ask': 59,
#               'no_bid': 51,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '97° to 98°',
#               'ticker': 'HIGHAUS-24OCT13-B97.5',
#               'title': 'Will the **high temp in Austin** be 97-98° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 49,
#               'yes_bid': 41},
#              {'can_close_early': True,
#               'cap_strike': 96,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T04:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHAUS-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 95,
#               'last_price': 3,
#               'liquidity': 63510,
#               'no_ask': 97,
#               'no_bid': 85,
#               'open_interest': 5,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '95° to 96°',
#               'ticker': 'HIGHAUS-24OCT13-B95.5',
#               'title': 'Will the **high temp in Austin** be 95-96° on Oct 13, '
#                        '2024?',
#               'volume': 5,
#               'volume_24h': 0,
#               'yes_ask': 15,
#               'yes_bid': 3},
#              {'can_close_early': True,
#               'cap_strike': 94,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T04:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHAUS-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 93,
#               'last_price': 0,
#               'liquidity': 95261,
#               'no_ask': 99,
#               'no_bid': 35,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '93° to 94°',
#               'ticker': 'HIGHAUS-24OCT13-B93.5',
#               'title': 'Will the **high temp in Austin** be 93-94° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 65,
#               'yes_bid': 1},
#              {'can_close_early': True,
#               'cap_strike': 93,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T04:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHAUS-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': None,
#               'last_price': 0,
#               'liquidity': 74791,
#               'no_ask': 99,
#               'no_bid': 35,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'less',
#               'subtitle': '92° or below',
#               'ticker': 'HIGHAUS-24OCT13-T93',
#               'title': 'Will the **high temp in Austin** be <93° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 65,
#               'yes_bid': 1},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHMIA-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 88,
#               'last_price': 0,
#               'liquidity': 81757,
#               'no_ask': 99,
#               'no_bid': 22,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'greater',
#               'subtitle': '89° or above',
#               'ticker': 'HIGHMIA-24OCT13-T88',
#               'title': 'Will the **high temp in Miami** be >88° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 78,
#               'yes_bid': 1},
#              {'can_close_early': True,
#               'cap_strike': 88,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHMIA-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 87,
#               'last_price': 0,
#               'liquidity': 101933,
#               'no_ask': 80,
#               'no_bid': 72,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '87° to 88°',
#               'ticker': 'HIGHMIA-24OCT13-B87.5',
#               'title': 'Will the **high temp in Miami** be 87-88° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 28,
#               'yes_bid': 20},
#              {'can_close_early': True,
#               'cap_strike': 86,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHMIA-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 85,
#               'last_price': 0,
#               'liquidity': 99980,
#               'no_ask': 52,
#               'no_bid': 44,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '85° to 86°',
#               'ticker': 'HIGHMIA-24OCT13-B85.5',
#               'title': 'Will the **high temp in Miami** be 85-86° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 56,
#               'yes_bid': 48},
#              {'can_close_early': True,
#               'cap_strike': 84,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHMIA-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 83,
#               'last_price': 0,
#               'liquidity': 53735,
#               'no_ask': 83,
#               'no_bid': 76,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '83° to 84°',
#               'ticker': 'HIGHMIA-24OCT13-B83.5',
#               'title': 'Will the **high temp in Miami** be 83-84° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 24,
#               'yes_bid': 17},
#              {'can_close_early': True,
#               'cap_strike': 81,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHMIA-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': None,
#               'last_price': 0,
#               'liquidity': 80763,
#               'no_ask': 99,
#               'no_bid': 21,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'less',
#               'subtitle': '80° or below',
#               'ticker': 'HIGHMIA-24OCT13-T81',
#               'title': 'Will the **high temp in Miami** be <81° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 79,
#               'yes_bid': 1},
#              {'can_close_early': True,
#               'cap_strike': 82,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHMIA-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 81,
#               'last_price': 0,
#               'liquidity': 73322,
#               'no_ask': 99,
#               'no_bid': 17,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '81° to 82°',
#               'ticker': 'HIGHMIA-24OCT13-B81.5',
#               'title': 'Will the **high temp in Miami** be 81-82° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 83,
#               'yes_bid': 1},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHNY-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 72,
#               'last_price': 0,
#               'liquidity': 121301,
#               'no_ask': 99,
#               'no_bid': 39,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'greater',
#               'subtitle': '73° or above',
#               'ticker': 'HIGHNY-24OCT13-T72',
#               'title': 'Will the **high temp in NYC** be >72° on Oct 13, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 61,
#               'yes_bid': 1},
#              {'can_close_early': True,
#               'cap_strike': 72,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHNY-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 71,
#               'last_price': 0,
#               'liquidity': 89858,
#               'no_ask': 63,
#               'no_bid': 48,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '71° to 72°',
#               'ticker': 'HIGHNY-24OCT13-B71.5',
#               'title': 'Will the **high temp in NYC** be 71-72° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 52,
#               'yes_bid': 37},
#              {'can_close_early': True,
#               'cap_strike': 70,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHNY-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 69,
#               'last_price': 0,
#               'liquidity': 57185,
#               'no_ask': 97,
#               'no_bid': 85,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '69° to 70°',
#               'ticker': 'HIGHNY-24OCT13-B69.5',
#               'title': 'Will the **high temp in NYC** be 69-70° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 15,
#               'yes_bid': 3},
#              {'can_close_early': True,
#               'cap_strike': 68,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHNY-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 67,
#               'last_price': 0,
#               'liquidity': 94001,
#               'no_ask': 99,
#               'no_bid': 25,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '67° to 68°',
#               'ticker': 'HIGHNY-24OCT13-B67.5',
#               'title': 'Will the **high temp in NYC** be 67-68° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 75,
#               'yes_bid': 1},
#              {'can_close_early': True,
#               'cap_strike': 66,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHNY-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 65,
#               'last_price': 0,
#               'liquidity': 120629,
#               'no_ask': 99,
#               'no_bid': 35,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '65° to 66°',
#               'ticker': 'HIGHNY-24OCT13-B65.5',
#               'title': 'Will the **high temp in NYC** be 65-66° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 65,
#               'yes_bid': 1},
#              {'can_close_early': True,
#               'cap_strike': 65,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHNY-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': None,
#               'last_price': 0,
#               'liquidity': 124094,
#               'no_ask': 99,
#               'no_bid': 35,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'less',
#               'subtitle': '64° or below',
#               'ticker': 'HIGHNY-24OCT13-T65',
#               'title': 'Will the **high temp in NYC** be <65° on Oct 13, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 65,
#               'yes_bid': 1},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHCHI-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 68,
#               'last_price': 0,
#               'liquidity': 100485,
#               'no_ask': 95,
#               'no_bid': 84,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'greater',
#               'subtitle': '69° or above',
#               'ticker': 'HIGHCHI-24OCT13-T68',
#               'title': 'Will the high temp in Chicago be >68° on Oct 13, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 16,
#               'yes_bid': 5},
#              {'can_close_early': True,
#               'cap_strike': 68,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHCHI-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 67,
#               'last_price': 0,
#               'liquidity': 92972,
#               'no_ask': 62,
#               'no_bid': 55,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '67° to 68°',
#               'ticker': 'HIGHCHI-24OCT13-B67.5',
#               'title': 'Will the high temp in Chicago be 67-68° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 45,
#               'yes_bid': 38},
#              {'can_close_early': True,
#               'cap_strike': 66,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHCHI-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 65,
#               'last_price': 0,
#               'liquidity': 56780,
#               'no_ask': 65,
#               'no_bid': 57,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '65° to 66°',
#               'ticker': 'HIGHCHI-24OCT13-B65.5',
#               'title': 'Will the high temp in Chicago be 65-66° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 43,
#               'yes_bid': 35},
#              {'can_close_early': True,
#               'cap_strike': 64,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHCHI-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 63,
#               'last_price': 0,
#               'liquidity': 96455,
#               'no_ask': 98,
#               'no_bid': 85,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '63° to 64°',
#               'ticker': 'HIGHCHI-24OCT13-B63.5',
#               'title': 'Will the high temp in Chicago be 63-64° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 15,
#               'yes_bid': 2},
#              {'can_close_early': True,
#               'cap_strike': 62,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHCHI-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 61,
#               'last_price': 0,
#               'liquidity': 93457,
#               'no_ask': 99,
#               'no_bid': 34,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '61° to 62°',
#               'ticker': 'HIGHCHI-24OCT13-B61.5',
#               'title': 'Will the high temp in Chicago be 61-62° on Oct 13, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 66,
#               'yes_bid': 1},
#              {'can_close_early': True,
#               'cap_strike': 61,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-14T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHCHI-24OCT13',
#               'expiration_time': '2024-10-20T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': None,
#               'last_price': 0,
#               'liquidity': 95258,
#               'no_ask': 99,
#               'no_bid': 35,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'less',
#               'subtitle': '60° or below',
#               'ticker': 'HIGHCHI-24OCT13-T61',
#               'title': 'Will the high temp in Chicago be <61° on Oct 13, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 65,
#               'yes_bid': 1},
#              {'can_close_early': False,
#               'cap_strike': None,
#               'category': 'Politics',
#               'close_time': '2024-10-18T15:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'APRPOTUS-24OCT18',
#               'expiration_time': '2024-10-18T15:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 42.4,
#               'last_price': 0,
#               'liquidity': 4328,
#               'no_ask': 99,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'greater',
#               'subtitle': '42.5 or above',
#               'ticker': 'APRPOTUS-24OCT18-T42.4',
#               'title': "Will the President's approval rating be above 42.4 "
#                        'according to RealClearPolitics?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 1},
#              {'can_close_early': False,
#               'cap_strike': 42.4,
#               'category': 'Politics',
#               'close_time': '2024-10-18T15:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'APRPOTUS-24OCT18',
#               'expiration_time': '2024-10-18T15:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 42.2,
#               'last_price': 0,
#               'liquidity': 4328,
#               'no_ask': 99,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '42.2 to 42.4',
#               'ticker': 'APRPOTUS-24OCT18-B42.3',
#               'title': "Will the President's approval rating be between 42.2 "
#                        'and 42.4 according to RealClearPolitics?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 1},
#              {'can_close_early': False,
#               'cap_strike': 42.1,
#               'category': 'Politics',
#               'close_time': '2024-10-18T15:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'APRPOTUS-24OCT18',
#               'expiration_time': '2024-10-18T15:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 41.9,
#               'last_price': 0,
#               'liquidity': 4328,
#               'no_ask': 99,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '41.9 to 42.1',
#               'ticker': 'APRPOTUS-24OCT18-B42.0',
#               'title': "Will the President's approval rating be between 41.9 "
#                        'and 42.1 according to RealClearPolitics?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 1},
#              {'can_close_early': False,
#               'cap_strike': 41.8,
#               'category': 'Politics',
#               'close_time': '2024-10-18T15:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'APRPOTUS-24OCT18',
#               'expiration_time': '2024-10-18T15:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 41.6,
#               'last_price': 0,
#               'liquidity': 4328,
#               'no_ask': 99,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '41.6 to 41.8',
#               'ticker': 'APRPOTUS-24OCT18-B41.7',
#               'title': "Will the President's approval rating be between 41.6 "
#                        'and 41.8 according to RealClearPolitics?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 1},
#              {'can_close_early': False,
#               'cap_strike': 41.5,
#               'category': 'Politics',
#               'close_time': '2024-10-18T15:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'APRPOTUS-24OCT18',
#               'expiration_time': '2024-10-18T15:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 41.3,
#               'last_price': 0,
#               'liquidity': 4328,
#               'no_ask': 99,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '41.3 to 41.5',
#               'ticker': 'APRPOTUS-24OCT18-B41.4',
#               'title': "Will the President's approval rating be between 41.3 "
#                        'and 41.5 according to RealClearPolitics?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 1},
#              {'can_close_early': False,
#               'cap_strike': 41.2,
#               'category': 'Politics',
#               'close_time': '2024-10-18T15:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'APRPOTUS-24OCT18',
#               'expiration_time': '2024-10-18T15:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 41,
#               'last_price': 0,
#               'liquidity': 4328,
#               'no_ask': 99,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '41.0 to 41.2',
#               'ticker': 'APRPOTUS-24OCT18-B41.1',
#               'title': "Will the President's approval rating be between 41.0 "
#                        'and 41.2 according to RealClearPolitics?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 1},
#              {'can_close_early': False,
#               'cap_strike': 40.9,
#               'category': 'Politics',
#               'close_time': '2024-10-18T15:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'APRPOTUS-24OCT18',
#               'expiration_time': '2024-10-18T15:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 40.7,
#               'last_price': 0,
#               'liquidity': 4328,
#               'no_ask': 99,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '40.7 to 40.9',
#               'ticker': 'APRPOTUS-24OCT18-B40.8',
#               'title': "Will the President's approval rating be between 40.7 "
#                        'and 40.9 according to RealClearPolitics?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 1},
#              {'can_close_early': False,
#               'cap_strike': 40.6,
#               'category': 'Politics',
#               'close_time': '2024-10-18T15:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'APRPOTUS-24OCT18',
#               'expiration_time': '2024-10-18T15:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 40.4,
#               'last_price': 0,
#               'liquidity': 4328,
#               'no_ask': 99,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '40.4 to 40.6',
#               'ticker': 'APRPOTUS-24OCT18-B40.5',
#               'title': "Will the President's approval rating be between 40.4 "
#                        'and 40.6 according to RealClearPolitics?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 1},
#              {'can_close_early': False,
#               'cap_strike': 40.4,
#               'category': 'Politics',
#               'close_time': '2024-10-18T15:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'APRPOTUS-24OCT18',
#               'expiration_time': '2024-10-18T15:00:00Z',
#               'expiration_value': '',
#               'floor_strike': None,
#               'last_price': 0,
#               'liquidity': 4328,
#               'no_ask': 99,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-12T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'less',
#               'subtitle': '40.3 or below',
#               'ticker': 'APRPOTUS-24OCT18-T40.4',
#               'title': "Will the President's approval rating be below 40.4 "
#                        'according to RealClearPolitics?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 1},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': 'Financials',
#               'close_time': '2024-10-14T20:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'NASDAQ100U-24OCT14',
#               'expiration_time': '2024-10-21T23:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 20271.97,
#               'last_price': 0,
#               'liquidity': 0,
#               'no_ask': 100,
#               'no_bid': 100,
#               'open_interest': 0,
#               'open_time': '2024-10-11T20:45:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'greater',
#               'subtitle': '20,271.98 or above',
#               'ticker': 'NASDAQ100U-24OCT14-T20271.97',
#               'title': 'Will the Nasdaq-100 be above 20271.97 at the end of '
#                        'Oct 14, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 0,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': 'Financials',
#               'close_time': '2024-10-14T20:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'INXU-24OCT14',
#               'expiration_time': '2024-10-21T23:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 5815.03,
#               'last_price': 0,
#               'liquidity': 0,
#               'no_ask': 100,
#               'no_bid': 100,
#               'open_interest': 0,
#               'open_time': '2024-10-11T20:45:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'greater',
#               'subtitle': '5,815.04 or above',
#               'ticker': 'INXU-24OCT14-T5815.03',
#               'title': 'Will the S&P 500 be above 5815.03 at the end of Oct '
#                        '14, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 0,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-13T04:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHAUS-24OCT12',
#               'expiration_time': '2024-10-19T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 98,
#               'last_price': 1,
#               'liquidity': 59594,
#               'no_ask': 100,
#               'no_bid': 90,
#               'open_interest': 60,
#               'open_time': '2024-10-11T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 94,
#               'previous_yes_bid': 1,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'greater',
#               'subtitle': '99° or above',
#               'ticker': 'HIGHAUS-24OCT12-T98',
#               'title': 'Will the **high temp in Austin** be >98° on Oct 12, '
#                        '2024?',
#               'volume': 60,
#               'volume_24h': 60,
#               'yes_ask': 10,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': 98,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-13T04:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHAUS-24OCT12',
#               'expiration_time': '2024-10-19T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 97,
#               'last_price': 1,
#               'liquidity': 32676,
#               'no_ask': 99,
#               'no_bid': 91,
#               'open_interest': 737,
#               'open_time': '2024-10-11T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 18,
#               'previous_yes_bid': 9,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '97° to 98°',
#               'ticker': 'HIGHAUS-24OCT12-B97.5',
#               'title': 'Will the **high temp in Austin** be 97-98° on Oct 12, '
#                        '2024?',
#               'volume': 882,
#               'volume_24h': 882,
#               'yes_ask': 9,
#               'yes_bid': 1},
#              {'can_close_early': True,
#               'cap_strike': 96,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-13T04:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHAUS-24OCT12',
#               'expiration_time': '2024-10-19T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 95,
#               'last_price': 56,
#               'liquidity': 101778,
#               'no_ask': 45,
#               'no_bid': 44,
#               'open_interest': 707,
#               'open_time': '2024-10-11T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 53,
#               'previous_yes_bid': 45,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '95° to 96°',
#               'ticker': 'HIGHAUS-24OCT12-B95.5',
#               'title': 'Will the **high temp in Austin** be 95-96° on Oct 12, '
#                        '2024?',
#               'volume': 707,
#               'volume_24h': 707,
#               'yes_ask': 56,
#               'yes_bid': 55},
#              {'can_close_early': True,
#               'cap_strike': 94,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-13T04:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHAUS-24OCT12',
#               'expiration_time': '2024-10-19T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 93,
#               'last_price': 37,
#               'liquidity': 227456,
#               'no_ask': 63,
#               'no_bid': 58,
#               'open_interest': 935,
#               'open_time': '2024-10-11T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 37,
#               'previous_yes_bid': 28,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '93° to 94°',
#               'ticker': 'HIGHAUS-24OCT12-B93.5',
#               'title': 'Will the **high temp in Austin** be 93-94° on Oct 12, '
#                        '2024?',
#               'volume': 955,
#               'volume_24h': 955,
#               'yes_ask': 42,
#               'yes_bid': 37},
#              {'can_close_early': True,
#               'cap_strike': 92,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-13T04:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHAUS-24OCT12',
#               'expiration_time': '2024-10-19T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 91,
#               'last_price': 2,
#               'liquidity': 27657,
#               'no_ask': 100,
#               'no_bid': 76,
#               'open_interest': 195,
#               'open_time': '2024-10-11T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 94,
#               'previous_yes_bid': 1,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '91° to 92°',
#               'ticker': 'HIGHAUS-24OCT12-B91.5',
#               'title': 'Will the **high temp in Austin** be 91-92° on Oct 12, '
#                        '2024?',
#               'volume': 195,
#               'volume_24h': 195,
#               'yes_ask': 24,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': 91,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-13T04:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHAUS-24OCT12',
#               'expiration_time': '2024-10-19T14:00:00Z',
#               'expiration_value': '',
#               'floor_strike': None,
#               'last_price': 1,
#               'liquidity': 26642,
#               'no_ask': 100,
#               'no_bid': 81,
#               'open_interest': 50,
#               'open_time': '2024-10-11T14:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 94,
#               'previous_yes_bid': 1,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'less',
#               'subtitle': '90° or below',
#               'ticker': 'HIGHAUS-24OCT12-T91',
#               'title': 'Will the **high temp in Austin** be <91° on Oct 12, '
#                        '2024?',
#               'volume': 50,
#               'volume_24h': 50,
#               'yes_ask': 19,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': 'Climate and Weather',
#               'close_time': '2024-10-13T03:59:00Z',
#               'custom_strike': None,
#               'event_ticker': 'HIGHMIA-24OCT12',
# ...
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '5,450 to 5,474.99',
#               'ticker': 'INX-24OCT18-B5462',
#               'title': 'Will the S&P 500 be between 5450 and 5474.99 at the '
#                        'end of Oct 18, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': 5449.99,
#               'category': 'Financials',
#               'close_time': '2024-10-18T20:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'INX-24OCT18',
#               'expiration_time': '2024-10-25T23:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 5425,
#               'last_price': 0,
#               'liquidity': 1960,
#               'no_ask': 100,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-11T20:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '5,425 to 5,449.99',
#               'ticker': 'INX-24OCT18-B5437',
#               'title': 'Will the S&P 500 be between 5425 and 5449.99 at the '
#                        'end of Oct 18, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': 5425,
#               'category': 'Financials',
#               'close_time': '2024-10-18T20:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'INX-24OCT18',
#               'expiration_time': '2024-10-25T23:00:00Z',
#               'expiration_value': '',
#               'floor_strike': None,
#               'last_price': 0,
#               'liquidity': 1960,
#               'no_ask': 100,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-11T20:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'less',
#               'subtitle': '5,424.99 or below',
#               'ticker': 'INX-24OCT18-T5425',
#               'title': 'Will the S&P 500 be below 5425 at the end of Oct 18, '
#                        '2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': None,
#               'category': 'Financials',
#               'close_time': '2024-10-18T20:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'NASDAQ100-24OCT18',
#               'expiration_time': '2024-10-25T23:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 21599.99,
#               'last_price': 0,
#               'liquidity': 1960,
#               'no_ask': 100,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-11T20:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'greater',
#               'subtitle': '21,600 or above',
#               'ticker': 'NASDAQ100-24OCT18-T21599.99',
#               'title': 'Will the Nasdaq-100 be above 21599.99 at the end of '
#                        'Oct 18, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': 21599.99,
#               'category': 'Financials',
#               'close_time': '2024-10-18T20:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'NASDAQ100-24OCT18',
#               'expiration_time': '2024-10-25T23:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 21500,
#               'last_price': 0,
#               'liquidity': 1960,
#               'no_ask': 100,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-11T20:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '21,500 to 21,599.99',
#               'ticker': 'NASDAQ100-24OCT18-B21550',
#               'title': 'Will the Nasdaq-100 be between 21500 and 21599.99 at '
#                        'the end of Oct 18, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': 21499.99,
#               'category': 'Financials',
#               'close_time': '2024-10-18T20:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'NASDAQ100-24OCT18',
#               'expiration_time': '2024-10-25T23:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 21400,
#               'last_price': 0,
#               'liquidity': 1960,
#               'no_ask': 100,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-11T20:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '21,400 to 21,499.99',
#               'ticker': 'NASDAQ100-24OCT18-B21450',
#               'title': 'Will the Nasdaq-100 be between 21400 and 21499.99 at '
#                        'the end of Oct 18, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': 21399.99,
#               'category': 'Financials',
#               'close_time': '2024-10-18T20:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'NASDAQ100-24OCT18',
#               'expiration_time': '2024-10-25T23:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 21300,
#               'last_price': 0,
#               'liquidity': 1960,
#               'no_ask': 100,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-11T20:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '21,300 to 21,399.99',
#               'ticker': 'NASDAQ100-24OCT18-B21350',
#               'title': 'Will the Nasdaq-100 be between 21300 and 21399.99 at '
#                        'the end of Oct 18, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': 21299.99,
#               'category': 'Financials',
#               'close_time': '2024-10-18T20:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'NASDAQ100-24OCT18',
#               'expiration_time': '2024-10-25T23:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 21200,
#               'last_price': 0,
#               'liquidity': 1960,
#               'no_ask': 100,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-11T20:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '21,200 to 21,299.99',
#               'ticker': 'NASDAQ100-24OCT18-B21250',
#               'title': 'Will the Nasdaq-100 be between 21200 and 21299.99 at '
#                        'the end of Oct 18, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': 21199.99,
#               'category': 'Financials',
#               'close_time': '2024-10-18T20:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'NASDAQ100-24OCT18',
#               'expiration_time': '2024-10-25T23:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 21100,
#               'last_price': 0,
#               'liquidity': 1960,
#               'no_ask': 100,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-11T20:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '21,100 to 21,199.99',
#               'ticker': 'NASDAQ100-24OCT18-B21150',
#               'title': 'Will the Nasdaq-100 be between 21100 and 21199.99 at '
#                        'the end of Oct 18, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': 21099.99,
#               'category': 'Financials',
#               'close_time': '2024-10-18T20:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'NASDAQ100-24OCT18',
#               'expiration_time': '2024-10-25T23:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 21000,
#               'last_price': 0,
#               'liquidity': 1960,
#               'no_ask': 100,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-11T20:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '21,000 to 21,099.99',
#               'ticker': 'NASDAQ100-24OCT18-B21050',
#               'title': 'Will the Nasdaq-100 be between 21000 and 21099.99 at '
#                        'the end of Oct 18, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': 20999.99,
#               'category': 'Financials',
#               'close_time': '2024-10-18T20:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'NASDAQ100-24OCT18',
#               'expiration_time': '2024-10-25T23:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 20900,
#               'last_price': 0,
#               'liquidity': 1960,
#               'no_ask': 100,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-11T20:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '20,900 to 20,999.99',
#               'ticker': 'NASDAQ100-24OCT18-B20950',
#               'title': 'Will the Nasdaq-100 be between 20900 and 20999.99 at '
#                        'the end of Oct 18, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': 20899.99,
#               'category': 'Financials',
#               'close_time': '2024-10-18T20:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'NASDAQ100-24OCT18',
#               'expiration_time': '2024-10-25T23:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 20800,
#               'last_price': 0,
#               'liquidity': 1960,
#               'no_ask': 100,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-11T20:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '20,800 to 20,899.99',
#               'ticker': 'NASDAQ100-24OCT18-B20850',
#               'title': 'Will the Nasdaq-100 be between 20800 and 20899.99 at '
#                        'the end of Oct 18, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': 20799.99,
#               'category': 'Financials',
#               'close_time': '2024-10-18T20:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'NASDAQ100-24OCT18',
#               'expiration_time': '2024-10-25T23:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 20700,
#               'last_price': 0,
#               'liquidity': 1960,
#               'no_ask': 100,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-11T20:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '20,700 to 20,799.99',
#               'ticker': 'NASDAQ100-24OCT18-B20750',
#               'title': 'Will the Nasdaq-100 be between 20700 and 20799.99 at '
#                        'the end of Oct 18, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 0},
#              {'can_close_early': True,
#               'cap_strike': 20699.99,
#               'category': 'Financials',
#               'close_time': '2024-10-18T20:00:00Z',
#               'custom_strike': None,
#               'event_ticker': 'NASDAQ100-24OCT18',
#               'expiration_time': '2024-10-25T23:00:00Z',
#               'expiration_value': '',
#               'floor_strike': 20600,
#               'last_price': 0,
#               'liquidity': 1960,
#               'no_ask': 100,
#               'no_bid': 2,
#               'open_interest': 0,
#               'open_time': '2024-10-11T20:00:00Z',
#               'previous_price': 0,
#               'previous_yes_ask': 0,
#               'previous_yes_bid': 0,
#               'result': '',
#               'risk_limit_cents': 0,
#               'status': 'active',
#               'strike_type': 'between',
#               'subtitle': '20,600 to 20,699.99',
#               'ticker': 'NASDAQ100-24OCT18-B20650',
#               'title': 'Will the Nasdaq-100 be between 20600 and 20699.99 at '
#                        'the end of Oct 18, 2024?',
#               'volume': 0,
#               'volume_24h': 0,
#               'yes_ask': 98,
#               'yes_bid': 0}]}

# %%
api.get_events()
# Out:
# {'cursor': 'CgYI_-jWuwYSDEVNTVlEQUNUUi0yMw',
#  'events': [{'category': 'Economics',
#              'event_ticker': 'JOBLESS-21AUG28',
#              'mutually_exclusive': False,
#              'series_ticker': 'JOBLESS',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'From Aug 22-28, 2021',
#              'title': 'Initial jobless claims from Aug 22-28, 2021?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'EUCLIMATE',
#              'mutually_exclusive': False,
#              'series_ticker': 'EUCLIMATE',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'By 2030',
#              'title': 'EU meets its 2030 climate goals?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'INDIACLIMATE-30',
#              'mutually_exclusive': False,
#              'series_ticker': 'INDIACLIMATE',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'By 2030',
#              'title': 'India meets its 2030 climate goals?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'USCLIMATE',
#              'mutually_exclusive': False,
#              'series_ticker': 'USCLIMATE',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': '2025/2030 goals',
#              'title': 'US meets its climate goals?'},
#             {'category': 'Science and Technology',
#              'event_ticker': 'AITURING',
#              'mutually_exclusive': False,
#              'series_ticker': 'AITURING',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2030',
#              'title': 'AI passes Turing test before 2030?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'EVSHARE-30JAN',
#              'mutually_exclusive': False,
#              'series_ticker': 'EVSHARE',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In Jan 2030',
#              'title': 'EV market share in 2030?'},
#             {'category': 'Politics',
#              'event_ticker': 'NONCOMPETEBAN',
#              'mutually_exclusive': False,
#              'series_ticker': 'NONCOMPETEBAN',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'By 2030',
#              'title': 'Non-compete ban overturned?'},
#             {'category': 'World',
#              'event_ticker': 'EUEXPANSION',
#              'mutually_exclusive': False,
#              'series_ticker': 'EUEXPANSION',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'By 2030',
#              'title': 'EU has a new member before 2030?'},
#             {'category': 'Politics',
#              'event_ticker': 'EUEXIT',
#              'mutually_exclusive': False,
#              'series_ticker': 'EUEXIT',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'By 2030',
#              'title': 'EU loses a member before 2030?'},
#             {'category': 'Economics',
#              'event_ticker': 'CHINAUSGDP',
#              'mutually_exclusive': False,
#              'series_ticker': 'CHINAUSGDP',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'By 2030',
#              'title': 'China overtakes USA’s economy by 2030?'},
#             {'category': 'Entertainment',
#              'event_ticker': 'BEYONCEGENRE-30',
#              'mutually_exclusive': False,
#              'series_ticker': 'BEYONCEGENRE',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Next Beyonce album genre',
#              'title': 'What genre will Beyonce’s next album be?'},
#             {'category': 'Politics',
#              'event_ticker': 'AMAZONFTC-29DEC31',
#              'mutually_exclusive': False,
#              'series_ticker': 'AMAZONFTC',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2030',
#              'title': 'Courts consider Amazon a monopoly?'},
#             {'category': 'Crypto',
#              'event_ticker': 'BTCETHATH-29DEC31',
#              'mutually_exclusive': False,
#              'series_ticker': 'BTCETHATH',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2030',
#              'title': 'Ethereum hits new all-time high before Bitcoin?'},
#             {'category': 'Companies',
#              'event_ticker': 'APPLEUS',
#              'mutually_exclusive': False,
#              'series_ticker': 'APPLEUS',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2030',
#              'title': 'Courts consider Apple a monopoly?'},
#             {'category': 'Companies',
#              'event_ticker': 'STARSHIPMARS',
#              'mutually_exclusive': False,
#              'series_ticker': 'STARSHIPMARS',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2030',
#              'title': 'Starship manned mission to Mars launched before 2030?'},
#             {'category': 'Politics',
#              'event_ticker': 'GOOGLEUS-28DEC31',
#              'mutually_exclusive': False,
#              'series_ticker': 'GOOGLEUS',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2029',
#              'title': 'Courts consider Google a monopoly?'},
#             {'category': 'Companies',
#              'event_ticker': 'OPENAISUIT',
#              'mutually_exclusive': False,
#              'series_ticker': 'OPENAISUIT',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2028',
#              'title': 'Elon Musk wins OpenAI lawsuit?'},
#             {'category': 'Science and Technology',
#              'event_ticker': 'NYTOAI-27DEC31',
#              'mutually_exclusive': False,
#              'series_ticker': 'NYTOAI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Copyright infringement',
#              'title': 'New York Times wins OpenAI lawsuit?'},
#             {'category': 'Politics',
#              'event_ticker': 'SCOTREF-27',
#              'mutually_exclusive': False,
#              'series_ticker': 'SCOTREF',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2027',
#              'title': 'Scottish referendum called before 2027?'},
#             {'category': 'Science and Technology',
#              'event_ticker': 'MOON',
#              'mutually_exclusive': False,
#              'series_ticker': 'MOON',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Moon landing',
#              'title': 'NASA lands on the moon?'},
#             {'category': 'Economics',
#              'event_ticker': 'WRECSS-26',
#              'mutually_exclusive': False,
#              'series_ticker': 'WRECSS',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2027',
#              'title': 'Which countries will have a recession?'},
#             {'category': 'Companies',
#              'event_ticker': 'TESLAOPTIMUS-26DEC31',
#              'mutually_exclusive': False,
#              'series_ticker': 'TESLAOPTIMUS',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2027',
#              'title': 'Tesla Optimus on sale before 2027?'},
#             {'category': 'Companies',
#              'event_ticker': 'TESLACEOCHANGE-26',
#              'mutually_exclusive': False,
#              'series_ticker': 'TESLACEOCHANGE',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2027',
#              'title': 'Elon Musk out as Tesla CEO before 2027?'},
#             {'category': 'Companies',
#              'event_ticker': 'APPLEFOLD',
#              'mutually_exclusive': False,
#              'series_ticker': 'APPLEFOLD',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Announcement',
#              'title': 'When will Apple announce foldable iPhone?'},
#             {'category': 'Companies',
#              'event_ticker': 'TIKTOKBAN-26JUN30',
#              'mutually_exclusive': False,
#              'series_ticker': 'TIKTOKBAN',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before July 2026',
#              'title': 'US bans TikTok before July 2026?'},
#             {'category': 'Entertainment',
#              'event_ticker': 'AVENGERSDELAY-26MAY01',
#              'mutually_exclusive': False,
#              'series_ticker': 'AVENGERSDELAY',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'By May 2026',
#              'title': 'New Avengers movie delayed?'},
#             {'category': 'Politics',
#              'event_ticker': 'USTESTSREADING-24',
#              'mutually_exclusive': True,
#              'series_ticker': 'USTESTSREADING',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2024',
#              'title': 'US test scores in Reading in 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'RECSSNBER-25',
#              'mutually_exclusive': False,
#              'series_ticker': 'RECSSNBER',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2026',
#              'title': 'Recession before 2026?'},
#             {'category': 'Companies',
#              'event_ticker': 'ROBOTAXIOUT-26',
#              'mutually_exclusive': False,
#              'series_ticker': 'ROBOTAXIOUT',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2026',
#              'title': 'Tesla robotaxi public release before 2026?'},
#             {'category': 'Politics',
#              'event_ticker': 'TEXASDHS-25DEC31',
#              'mutually_exclusive': False,
#              'series_ticker': 'TEXASDHS',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Border wire case',
#              'title': 'Texas loses border fight with Feds?'},
#             {'category': 'Companies',
#              'event_ticker': 'TIKTOKBAN-25DEC31',
#              'mutually_exclusive': False,
#              'series_ticker': 'TIKTOKBAN',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2026',
#              'title': 'US bans TikTok before 2026?'},
#             {'category': 'Companies',
#              'event_ticker': 'TESLAROADSTER-25',
#              'mutually_exclusive': False,
#              'series_ticker': 'TESLAROADSTER',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2026',
#              'title': 'Tesla Roadsters delivered before 2026?'},
#             {'category': 'Entertainment',
#              'event_ticker': 'PS6-26',
#              'mutually_exclusive': False,
#              'series_ticker': 'PS6',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2026',
#              'title': 'PS6 announced before 2026?'},
#             {'category': 'Politics',
#              'event_ticker': 'NPRDEFUND-25',
#              'mutually_exclusive': False,
#              'series_ticker': 'NPRDEFUND',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2026',
#              'title': 'Congress defunds NPR before 2026?'},
#             {'category': 'Companies',
#              'event_ticker': 'MSFTCEO-25',
#              'mutually_exclusive': False,
#              'series_ticker': 'MSFTCEO',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2026',
#              'title': 'New Microsoft CEO before 2026?'},
#             {'category': 'Science and Technology',
#              'event_ticker': 'IMOAI',
#              'mutually_exclusive': False,
#              'series_ticker': 'IMOAI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2026',
#              'title': 'AI wins IMO gold medal before 2026?'},
#             {'category': 'Entertainment',
#              'event_ticker': 'GTA6',
#              'mutually_exclusive': False,
#              'series_ticker': 'GTA6',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'GTA 6',
#              'title': 'GTA 6 release date?'},
#             {'category': 'Politics',
#              'event_ticker': 'FBUSTER-25DEC31',
#              'mutually_exclusive': False,
#              'series_ticker': 'FBUSTER',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2026',
#              'title': 'Filibuster weakened before 2026?'},
#             {'category': 'Politics',
#              'event_ticker': 'CAPGAIN-2-25DEC31',
#              'mutually_exclusive': False,
#              'series_ticker': 'CAPGAIN',
#              'strike_date': '2025-12-31T15:00:00Z',
#              'strike_period': None,
#              'sub_title': 'Before 2026',
#              'title': 'Capital gains tax increase before 2026?'},
#             {'category': 'Economics',
#              'event_ticker': 'WTAX-25',
#              'mutually_exclusive': False,
#              'series_ticker': 'WTAX',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2026',
#              'title': 'Will a tax on unrealized capital gains become law '
#                       'before 2026?'},
#             {'category': 'Politics',
#              'event_ticker': 'USTESTSMATH-24',
#              'mutually_exclusive': False,
#              'series_ticker': 'USTESTSMATH',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2024',
#              'title': 'US test scores in Math in 2024?'},
#             {'category': 'Companies',
#              'event_ticker': 'TESLACEOCHANGE-25',
#              'mutually_exclusive': False,
#              'series_ticker': 'TESLACEOCHANGE',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2026',
#              'title': 'Elon Musk out as Tesla CEO before 2026?'},
#             {'category': 'Entertainment',
#              'event_ticker': 'RTWITCHERS4',
#              'mutually_exclusive': False,
#              'series_ticker': 'RTWITCHERS4',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Day after the premiere',
#              'title': '"The Witcher: Season 4" Rotten Tomatoes score?'},
#             {'category': 'Entertainment',
#              'event_ticker': 'OSCARNOMSUPACTO-25',
#              'mutually_exclusive': False,
#              'series_ticker': 'OSCARNOMSUPACTO',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2025',
#              'title': 'Oscar nominations for Best Supporting Actor?'},
#             {'category': 'Entertainment',
#              'event_ticker': 'OSCARNOMPIC-25',
#              'mutually_exclusive': False,
#              'series_ticker': 'OSCARNOMPIC',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2025',
#              'title': 'Oscar nominations for Best Picture?'},
#             {'category': 'Entertainment',
#              'event_ticker': 'OSCARNOMACTR-25',
#              'mutually_exclusive': False,
#              'series_ticker': 'OSCARNOMACTR',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2025',
#              'title': 'Oscar nominations for Best Actress?'},
#             {'category': 'Entertainment',
#              'event_ticker': 'OSCARNOMACTO-25',
#              'mutually_exclusive': False,
#              'series_ticker': 'OSCARNOMACTO',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2025',
#              'title': 'Oscar nominations for Best Actor?'},
#             {'category': 'Politics',
#              'event_ticker': 'NETCHOICE',
#              'mutually_exclusive': False,
#              'series_ticker': 'NETCHOICE',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'By Dec 31, 2025',
#              'title': 'SCOTUS prohibits Texas social media regulations?'},
#             {'category': 'Politics',
#              'event_ticker': 'LEAVEPOWELL-25',
#              'mutually_exclusive': False,
#              'series_ticker': 'LEAVEPOWELL',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2026',
#              'title': 'Powell out as Chair before 2026?'},
#             {'category': 'Entertainment',
#              'event_ticker': 'IRONMAN',
#              'mutually_exclusive': False,
#              'series_ticker': 'IRONMAN',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2026',
#              'title': 'Iron Man returns to Marvel before 2026?'},
#             {'category': 'Politics',
#              'event_ticker': 'GRANTSPASS',
#              'mutually_exclusive': False,
#              'series_ticker': 'GRANTSPASS',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'By Dec 31, 2025',
#              'title': 'SCOTUS authorizes kicking homeless people out of public '
#                       'property?'},
#             {'category': 'Economics',
#              'event_ticker': 'FEDHIKE',
#              'mutually_exclusive': False,
#              'series_ticker': 'FEDHIKE',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Fed rate hike',
#              'title': 'Next Fed rate hike?'},
#             {'category': 'Politics',
#              'event_ticker': 'CFPB-25DEC31',
#              'mutually_exclusive': False,
#              'series_ticker': 'CFPB',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2026',
#              'title': 'SCOTUS considers CFPB unconstitutional?'},
#             {'category': 'Companies',
#              'event_ticker': 'APPLEPORT-25DEC31',
#              'mutually_exclusive': False,
#              'series_ticker': 'APPLEPORT',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2026',
#              'title': 'Apple reveals portless iPhone before 2026?'},
#             {'category': 'Politics',
#              'event_ticker': 'AILEGISLATION-25',
#              'mutually_exclusive': False,
#              'series_ticker': 'AILEGISLATION',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2026',
#              'title': 'AI regulation becomes federal law before 2026?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-25DEC',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2025-12-10T19:00:00Z',
#              'strike_period': None,
#              'sub_title': 'On Dec 10, 2025',
#              'title': 'Fed funds rate in Dec 2025?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-25OCT',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2025-10-29T18:00:00Z',
#              'strike_period': None,
#              'sub_title': 'On Oct 29, 2025',
#              'title': 'Fed funds rate in Oct 2025?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-25SEP',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2025-09-17T18:00:00Z',
#              'strike_period': None,
#              'sub_title': 'On Sep 17, 2025',
#              'title': 'Fed funds rate in Sep 2025?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-25JUL',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2025-07-30T18:00:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jul 30, 2025',
#              'title': 'Fed funds rate in Jul 2025?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-25JUN',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2025-06-18T18:00:00Z',
#              'strike_period': None,
#              'sub_title': 'On Jun 18, 2025',
#              'title': 'Fed funds rate in Jun 2025?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-25MAY',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2025-05-07T18:00:00Z',
#              'strike_period': None,
#              'sub_title': 'On May 7, 2025',
#              'title': 'Fed funds rate in May 2025?'},
#             {'category': 'Companies',
#              'event_ticker': 'TIKTOKBAN-25APR30',
#              'mutually_exclusive': False,
#              'series_ticker': 'TIKTOKBAN',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before May 2025',
#              'title': 'US bans TikTok before May 2025?'},
#             {'category': 'Entertainment',
#              'event_ticker': 'BELICHICK-25',
#              'mutually_exclusive': False,
#              'series_ticker': 'BELICHICK',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before May 2025',
#              'title': 'Bill Belichick gets a head coaching job before May '
#                       '2025?'},
#             {'category': 'Politics',
#              'event_ticker': 'HARVARD-25MAR31',
#              'mutually_exclusive': False,
#              'series_ticker': 'HARVARD',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2025',
#              'title': 'Harvard application numbers in 2025?'},
#             {'category': 'Climate and Weather',
#              'event_ticker': 'GTEMP-24',
#              'mutually_exclusive': False,
#              'series_ticker': 'GTEMP',
#              'strike_date': None,
#              'strike_period': '2024',
#              'sub_title': 'In 2024',
#              'title': 'Is this year the hottest year ever?'},
#             {'category': 'Economics',
#              'event_ticker': 'CREDEF-24-Q4',
#              'mutually_exclusive': False,
#              'series_ticker': 'CREDEF',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In Q4 2024',
#              'title': 'Commercial real estate defaults in Q4 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-25MAR',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2025-03-19T18:00:00Z',
#              'strike_period': None,
#              'sub_title': 'On Mar 19, 2025',
#              'title': 'Fed funds rate in Mar 2025?'},
#             {'category': 'Entertainment',
#              'event_ticker': 'OSCARCOUNTDUNE2',
#              'mutually_exclusive': True,
#              'series_ticker': 'OSCARCOUNTDUNE2',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'At the 2025 Oscars',
#              'title': 'How many Oscars “Dune: Part Two” will win?'},
#             {'category': 'Economics',
#              'event_ticker': 'LAYOFFSYINFO-24',
#              'mutually_exclusive': False,
#              'series_ticker': 'LAYOFFSYINFO',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2024',
#              'title': 'Tech layoffs up in 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'CREDEFMAX-24-Q4',
#              'mutually_exclusive': False,
#              'series_ticker': 'CREDEFMAX',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'By Dec 2024',
#              'title': 'How high will the commercial real estate default rate '
#                       'get in 2024?'},
#             {'category': 'Companies',
#              'event_ticker': 'NETFLIXSUBS-24-Q4',
#              'mutually_exclusive': False,
#              'series_ticker': 'NETFLIXSUBS',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In Q4 2024',
#              'title': 'Netflix subscribers gain in Q4 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'RECSSNBER-24',
#              'mutually_exclusive': False,
#              'series_ticker': 'RECSSNBER',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2025',
#              'title': 'Recession in 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'REALWAGES-24',
#              'mutually_exclusive': False,
#              'series_ticker': 'REALWAGES',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2024',
#              'title': 'Will wages grow more than inflation in 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'RATECUT-25JAN29',
#              'mutually_exclusive': False,
#              'series_ticker': 'RATECUT',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before Jan 30, 2025',
#              'title': 'Fed rate cut before Jan 30th?'},
#             {'category': 'Economics',
#              'event_ticker': 'FED-25JAN',
#              'mutually_exclusive': False,
#              'series_ticker': 'FED',
#              'strike_date': '2025-01-29T19:00:00Z',
#              'strike_period': None,
#              'sub_title': 'In Jan 29, 2025',
#              'title': 'Fed funds rate in Jan 2025?'},
#             {'category': 'Economics',
#              'event_ticker': 'SEMIPRODH-24',
#              'mutually_exclusive': False,
#              'series_ticker': 'SEMIPRODH',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2024',
#              'title': 'US semiconductor production growth in 2024?'},
#             {'category': 'Science and Technology',
#              'event_ticker': 'MEISSNER-2431DEC',
#              'mutually_exclusive': False,
#              'series_ticker': 'MEISSNER',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2024',
#              'title': 'Meissner effect confirmed near room temperature in '
#                       '2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'SFRENTSY-24',
#              'mutually_exclusive': False,
#              'series_ticker': 'SFRENTSY',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2024',
#              'title': 'Rent price increase in SF in 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'RENTNYCY-24DEC',
#              'mutually_exclusive': False,
#              'series_ticker': 'RENTNYCY',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2024',
#              'title': 'Rent price increase in NYC in 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'HOMEUSY-24',
#              'mutually_exclusive': False,
#              'series_ticker': 'HOMEUSY',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2024',
#              'title': 'Housing price increase in the US in 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'ACPICORE-2024',
#              'mutually_exclusive': True,
#              'series_ticker': 'ACPICORE-',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2024',
#              'title': 'Core inflation in 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'ACPI-2024',
#              'mutually_exclusive': True,
#              'series_ticker': 'ACPI',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2024',
#              'title': 'Inflation in 2024?'},
#             {'category': 'Science and Technology',
#              'event_ticker': 'WEIGHTDRUGSQ-4-24',
#              'mutually_exclusive': False,
#              'series_ticker': 'WEIGHTDRUGSQ',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In Q4 2024',
#              'title': 'Ozempic and Wegovy prescriptions increase in Q4 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'LCPIMAXYOY-24',
#              'mutually_exclusive': False,
#              'series_ticker': 'LCPIMAXYOY',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2024',
#              'title': 'How high will the inflation level get in 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'BANKRUPTSY-24',
#              'mutually_exclusive': False,
#              'series_ticker': 'BANKRUPTSY',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2024',
#              'title': 'How many companies will go bankrupt in 2024?'},
#             {'category': 'Politics',
#              'event_ticker': 'SCOTUSN-24DEC31',
#              'mutually_exclusive': False,
#              'series_ticker': 'SCOTUSN',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2024',
#              'title': 'New Supreme Court justice confirmed in 2024?'},
#             {'category': 'Companies',
#              'event_ticker': 'TESLAPROD-24-Q4',
#              'mutually_exclusive': False,
#              'series_ticker': 'TESLAPROD',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In Q4 2024',
#              'title': 'Tesla production in Q4 2024?'},
#             {'category': 'Companies',
#              'event_ticker': 'TESLA-24-Q4',
#              'mutually_exclusive': False,
#              'series_ticker': 'TESLA',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In Q4 2024',
#              'title': 'Tesla deliveries in Q4 2024?'},
#             {'category': 'Health',
#              'event_ticker': 'MEASLES-24',
#              'mutually_exclusive': False,
#              'series_ticker': 'MEASLES',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2024',
#              'title': 'Measles cases in 2024?'},
#             {'category': 'Entertainment',
#              'event_ticker': 'TOPALBUMROCKY-25',
#              'mutually_exclusive': False,
#              'series_ticker': 'TOPALBUMROCKY',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2025',
#              'title': 'ASAP Rocky has a #1 album in 2024?'},
#             {'category': 'Entertainment',
#              'event_ticker': 'RIHANNA',
#              'mutually_exclusive': False,
#              'series_ticker': 'RIHANNA',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2025',
#              'title': 'New Rihanna album in 2024?'},
#             {'category': 'Economics',
#              'event_ticker': 'NGASMAX-24DEC30',
#              'mutually_exclusive': False,
#              'series_ticker': 'NGASMAX',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2024',
#              'title': 'How high will natural gas get in 2024?'},
#             {'category': 'Politics',
#              'event_ticker': 'IVYFUNDING-25',
#              'mutually_exclusive': False,
#              'series_ticker': 'IVYFUNDING',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2025',
#              'title': 'Ivy Leagues lose federal funding in 2024?'},
#             {'category': 'Politics',
#              'event_ticker': 'COLUMBPRESIDENT-25',
#              'mutually_exclusive': False,
#              'series_ticker': 'COLUMBPRESIDENT',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2025',
#              'title': "Columbia's President ousted in 2024?"},
#             {'category': 'Entertainment',
#              'event_ticker': 'OSCARPIC-24',
#              'mutually_exclusive': False,
#              'series_ticker': 'OSCARPIC',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'In 2024',
#              'title': '2024 Oscar for Best Picture?'},
#             {'category': 'Science and Technology',
#              'event_ticker': 'AOH1996-2431DEC',
#              'mutually_exclusive': False,
#              'series_ticker': 'AOH1996',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Before 2025',
#              'title': 'New cancer drug passes phase 1 trial this year?'},
#             {'category': 'Crypto',
#              'event_ticker': 'ETHATH-24',
#              'mutually_exclusive': False,
#              'series_ticker': 'ETHATH',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'All-time high',
#              'title': 'When will Ethereum hit a new all-time high?'},
#             {'category': 'Companies',
#              'event_ticker': 'TESLAM2',
#              'mutually_exclusive': False,
#              'series_ticker': 'TESLAM2',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': 'Low-cost car announced',
#              'title': 'Tesla reveals low-cost car?'},
#             {'category': 'Entertainment',
#              'event_ticker': 'EMMYCACTO-23',
#              'mutually_exclusive': False,
#              'series_ticker': 'EMMYCACTO',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': '75th Emmys',
#              'title': '75th Emmys Award for Lead Comedy Actor?'},
#             {'category': 'Entertainment',
#              'event_ticker': 'EMMYDACTR-23',
#              'mutually_exclusive': False,
#              'series_ticker': 'EMMYDACTR',
#              'strike_date': None,
#              'strike_period': None,
#              'sub_title': '75th Emmys',
#              'title': '75th Emmys Award for Lead Drama Actress?'}]}
