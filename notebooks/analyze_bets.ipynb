# %%
import os

if os.path.basename(os.getcwd()) == 'notebooks':
    os.chdir('..')
    
os.getcwd()
# Out:
# '/home/zack/personal/prediction_market_tools'

# %%
import pandas as pd

# %%
p = pd.read_csv('data/raw/predsnprices.csv')

# %%
from src import expected_value

# %%
p, latest_p = expected_value.prep_prices_csv(p)
# Out:
# /home/zack/personal/prediction_market_tools/src/expected_value.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latest_p["buyYes"] = latest_p.myBet > latest_p.yesPrice
# /home/zack/miniconda3/envs/preds/lib/python3.9/site-packages/pandas/core/frame.py:3636: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /home/zack/personal/prediction_market_tools/src/expected_value.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   latest_p["expected_value"] = (latest_p.myp * latest_p.mktq) - (

# %%
latest_p
# Out:
#          symbol       date  yesPrice  noPrice  myBet purchase    qty  buyYes  \
# 6      VOHC-001 2021-09-14      0.36     0.66   0.25        n   98.0   False
# 7    NYSCHL-001 2021-09-14      0.84     0.17   0.90        y  125.0    True
# 9      CASE-038 2021-09-14      0.07     0.95   0.05      NaN    NaN   False
# 14     CASE-039 2021-09-15      0.06      NaN   0.05      NaN    NaN   False
# 16     CASE-040 2021-09-16      0.98     0.03   1.00      NaN    NaN    True
# 18   WKCASE-004 2021-09-16      0.99     0.02   1.00      NaN    NaN    True
# 20     CASE-041 2021-09-17      0.50     0.50   0.70      NaN    NaN    True
# 21     CASE-042 2021-09-17      0.34     0.66   0.25      NaN    NaN   False
# 22     CASE-042 2021-09-17      0.81     0.21   0.75      NaN    NaN   False
# 23     CASE-042 2021-09-17       NaN     0.65   0.90      NaN    NaN   False
# 25    LCASE-001 2021-09-20      0.09     0.96   0.10      NaN    NaN    True
# 26    LCASE-002 2021-09-20      0.13     0.90   0.15      NaN    NaN    True
# 27     FLUV-001 2021-09-20      0.19     0.96   0.10      NaN    NaN   False
# 28  RAINNYC-009 2021-09-20       NaN     0.85   0.10      NaN    NaN   False
# 29     CASE-043 2021-09-20      0.05      NaN   0.01      NaN    NaN   False
# 30    NHIGH-047 2021-09-20      0.01     0.01   0.55      NaN    NaN    True
#
#     mktp   myp  mktq   myq  expected_value
# 6   0.66  0.75  0.34  0.25            0.09
# 7   0.84  0.90  0.16  0.10            0.06
# 9   0.95  0.95  0.05  0.05            0.00
# 14   NaN  0.95   NaN  0.05             NaN
# 16  0.98  1.00  0.02  0.00            0.02
# 18  0.99  1.00  0.01  0.00            0.01
# 20  0.50  0.70  0.50  0.30            0.20
# 21  0.66  0.75  0.34  0.25            0.09
# 22  0.21  0.25  0.79  0.75            0.04
# 23  0.65  0.10  0.35  0.90           -0.55
# 25  0.09  0.10  0.91  0.90            0.01
# 26  0.13  0.15  0.87  0.85            0.02
# 27  0.96  0.90  0.04  0.10           -0.06
# 28  0.85  0.90  0.15  0.10            0.05
# 29   NaN  0.99   NaN  0.01             NaN
# 30  0.01  0.55  0.99  0.45            0.54

# %%
from src import kalshi

# %%
k = kalshi.Kalshi()

# %%
k.login()

# %%
markets = k.select_markets_by_ticker(latest_p.symbol)
markets
# Out:
#                                       id  \
# 0   2f485e17-27ac-4337-ad04-d63a9fc578ad
# 1   c549ccac-ad50-4f41-a1d1-771745ee97e5
# 2   11e5e5bf-d342-48ee-b1d0-cbf11ed34992
# 3   32f3aaa7-dc08-47f4-9b43-c5c47b47ae1b
# 4   b9689b80-9810-4bbd-b48a-8c637be5f056
# 5   bbfa850b-811e-4a68-b3b1-6ccd5b6ac9d3
# 6   257bebb5-1641-4a27-882d-bab2bfe06b5f
# 7   df5ada35-1129-43e2-a775-e91acc172d8f
# 8   df5ada35-1129-43e2-a775-e91acc172d8f
# 9   df5ada35-1129-43e2-a775-e91acc172d8f
# 10  654e1b59-9979-403d-af50-35434a440e1b
# 11  4dd57553-dd3c-4308-a284-9b319c5cce60
# 12  aa34fbc6-7514-484d-af16-888fd70e949c
# 13  1459b052-de7f-4336-aacf-081bba01c54b
# 14  b18273c3-1dab-4dcc-aa55-96caf7ba42e6
# 15  bf6e42be-352a-4697-9ffb-be4371dd3ef5
#
#                                                 title             category  \
# 0   Will the CDC identify a variant of high conseq...             COVID-19
# 1   Will New York public schools remain fully open...             COVID-19
# 2   Will there be over 160,000 new COVID-19 cases ...             COVID-19
# 3   Will there be over 150,000 new COVID-19 cases ...             COVID-19
# 4   Will there be over 140,000 new COVID-19 cases ...             COVID-19
# 5   Will there be over 980,000 new COVID-19 cases ...             COVID-19
# 6   Will there be over 130,000 new COVID-19 cases ...             COVID-19
# 7   Will there be over 140,000 new COVID-19 cases ...             COVID-19
# 8   Will there be over 140,000 new COVID-19 cases ...             COVID-19
# 9   Will there be over 140,000 new COVID-19 cases ...             COVID-19
# 10  Will there be a day with at least 200,000 new ...             COVID-19
# 11  Will there be a day with at least 200,000 new ...             COVID-19
# 12  Will the FDA give emergency authorization for ...             COVID-19
# 13          Will it rain in New York City on Tuesday?  Climate and Weather
# 14  Will there be over 140,000 new COVID-19 cases ...             COVID-19
# 15  Will the high in New York City be over 76° on ...  Climate and Weather
#
#                                        tags  \
# 0                       [COVID-19, Variant]
# 1                     [New York, Education]
# 2                            [COVID, Cases]
# 3                            [COVID, Cases]
# 4                            [COVID, Cases]
# 5                    [COVID, Cases, Weekly]
# 6                            [COVID, Cases]
# 7                            [COVID, Cases]
# 8                            [COVID, Cases]
# 9                            [COVID, Cases]
# 10               [COVID-19, Cases, Minimum]
# 11               [COVID-19, Cases, Minimum]
# 12                  [Covid-19, fluvoxamine]
# 13                                   [Rain]
# 14                           [COVID, Cases]
# 15  [Climate, Temperature, New York, Daily]
#
#                                     ranged_group_name  \
# 0       The CDC’s SARS-CoV-2 Variant Classifications.
# 1   The reopening plans of the New York City publi...
# 2   The number of new cases of COVID-19 published ...
# 3   The number of new cases of COVID-19 published ...
# 4   The number of new cases of COVID-19 published ...
# 5   The total sum of reported new COVID-19 cases p...
# 6   The number of new cases of COVID-19 published ...
# 7   The number of new cases of COVID-19 published ...
# 8   The number of new cases of COVID-19 published ...
# 9   The number of new cases of COVID-19 published ...
# 10  The reported number of new cases of COVID-19 p...
# 11  The reported number of new cases of COVID-19 p...
# 12    Press announcements issued by the FDA Newsroom.
# 13  The number of inches of precipitation recorded...
# 14  The number of new cases of COVID-19 published ...
# 15  The highest temperature recorded in Central Pa...
#
#                                             image_url min_tick_size  \
# 0   https://kalshi-public-images.s3.us-east-2.amaz...         $0.01
# 1   https://kalshi-public-images.s3.us-east-2.amaz...         $0.01
# 2   https://kalshi-public-images.s3.us-east-2.amaz...         $0.01
# 3   https://kalshi-public-images.s3.us-east-2.amaz...         $0.01
# 4   https://kalshi-public-images.s3.us-east-2.amaz...         $0.01
# 5   https://kalshi-public-images.s3.us-east-2.amaz...         $0.01
# 6   https://kalshi-public-images.s3.us-east-2.amaz...         $0.01
# 7   https://kalshi-public-images.s3.us-east-2.amaz...         $0.01
# 8   https://kalshi-public-images.s3.us-east-2.amaz...         $0.01
# 9   https://kalshi-public-images.s3.us-east-2.amaz...         $0.01
# 10  https://kalshi-public-images.s3.us-east-2.amaz...         $0.01
# 11  https://kalshi-public-images.s3.us-east-2.amaz...         $0.01
# 12  https://kalshi-public-images.s3.us-east-2.amaz...         $0.01
# 13  https://kalshi-public-images.s3.us-east-2.amaz...         $0.01
# 14  https://kalshi-public-images.s3.us-east-2.amaz...         $0.01
# 15  https://kalshi-public-images.s3.us-east-2.amaz...         $0.01
#
#                                        settle_details  \
# 0   If the CDC identifies a variant of high conseq...
# 1   If New York City public schools remain fully o...
# 2   If the number of new cases of COVID-19 reporte...
# 3   If the number of new cases of COVID-19 reporte...
# 4   If the number of new cases of COVID-19 reporte...
# 5   If the total number of reported new COVID-19 c...
# 6   If the number of new cases of COVID-19 reporte...
# 7   If the number of new cases of COVID-19 reporte...
# 8   If the number of new cases of COVID-19 reporte...
# 9   If the number of new cases of COVID-19 reporte...
# 10  If the number of reported new COVID-19 cases i...
# 11  If the number of reported new COVID-19 cases i...
# 12  If the FDA issues a press announcement authori...
# 13  If the number of inches of precipitation recor...
# 14  If the number of new cases of COVID-19 reporte...
# 15  If the highest temperature recorded in Central...
#
#                                    settlement_sources  ticker_name  ...  \
# 0   [{'url': 'https://www.cdc.gov/coronavirus/2019...     VOHC-001  ...
# 1   [{'url': 'https://www.schools.nyc.gov/', 'name...   NYSCHL-001  ...
# 2   [{'url': 'https://covid.cdc.gov/covid-data-tra...     CASE-038  ...
# 3   [{'url': 'https://covid.cdc.gov/covid-data-tra...     CASE-039  ...
# 4   [{'url': 'https://covid.cdc.gov/covid-data-tra...     CASE-040  ...
# 5   [{'url': 'https://covid.cdc.gov/covid-data-tra...   WKCASE-004  ...
# 6   [{'url': 'https://covid.cdc.gov/covid-data-tra...     CASE-041  ...
# 7   [{'url': 'https://covid.cdc.gov/covid-data-tra...     CASE-042  ...
# 8   [{'url': 'https://covid.cdc.gov/covid-data-tra...     CASE-042  ...
# 9   [{'url': 'https://covid.cdc.gov/covid-data-tra...     CASE-042  ...
# 10  [{'url': 'https://covid.cdc.gov/covid-data-tra...    LCASE-001  ...
# 11  [{'url': 'https://covid.cdc.gov/covid-data-tra...    LCASE-002  ...
# 12  [{'url': 'https://www.fda.gov/news-events/fda-...     FLUV-001  ...
# 13  [{'url': 'https://www.weather.gov/wrh/Climate?...  RAINNYC-009  ...
# 14  [{'url': 'https://covid.cdc.gov/covid-data-tra...     CASE-043  ...
# 15  [{'url': 'https://www.weather.gov/wrh/Climate?...    NHIGH-047  ...
#
#    yes_ask last_price previous_yes_bid previous_yes_ask previous_price  \
# 0     0.30       0.26             0.29             0.30           0.30
# 1     1.00       0.84             0.83             1.00           0.84
# 2     0.01       0.01             0.00             0.01           0.01
# 3     0.01       0.01             0.00             0.01           0.01
# 4     1.00       0.98             0.99             1.00           0.98
# 5     1.00       0.99             0.99             1.00           0.99
# 6     1.00       0.99             0.99             1.00           0.99
# 7     1.00       0.76             0.99             1.00           0.76
# 8     1.00       0.76             0.99             1.00           0.76
# 9     1.00       0.76             0.99             1.00           0.76
# 10    0.05       0.05             0.03             0.09           0.03
# 11    0.12       0.13             0.10             0.13           0.13
# 12    0.19       0.17             0.01             0.17           0.15
# 13    1.00       0.15             0.15             1.00           0.00
# 14    0.01       0.00             0.00             0.05           0.00
# 15    1.00       0.50             0.01             0.49           0.49
#
#     volume recent_volume open_interest result no_ask
# 0     2734           178          2392          0.80
# 1     5088             0          2896          1.00
# 2     8532          3464          5864     no   1.00
# 3     7638          4200          3982     no   1.00
# 4     5748             0          1574    yes   0.01
# 5    15978             0         11516    yes   0.01
# 6     4572          4572          4572    yes   0.01
# 7      580             0           556    yes   0.01
# 8      580             0           556    yes   0.01
# 9      580             0           556    yes   0.01
# 10  132640          2990         22128          0.97
# 11     600           600           600          0.90
# 12    2650           472          1178          0.96
# 13     100           100           100          0.85
# 14       0             0             0          1.00
# 15     126           126           126          0.65
#
# [16 rows x 31 columns]

# %%
bets = latest_p[['symbol','date','myBet']].merge(markets, how='left', left_on='symbol', right_on='ticker_name')

# %%
bets = bets[bets.status == 'active']

# %%
bets.columns
# Out:
# Index(['symbol', 'date', 'myBet', 'id', 'title', 'category', 'tags',
#        'ranged_group_name', 'image_url', 'min_tick_size', 'settle_details',
#        'settlement_sources', 'ticker_name', 'create_date', 'list_date',
#        'open_date', 'close_date', 'expiration_date', 'status',
#        'expiration_value', 'description_context', 'description_case_yes',
#        'description_case_no', 'yes_bid', 'yes_ask', 'last_price',
#        'previous_yes_bid', 'previous_yes_ask', 'previous_price', 'volume',
#        'recent_volume', 'open_interest', 'result', 'no_ask'],
#       dtype='object')

# %%
bets
# Out:
#          symbol       date  myBet                                    id  \
# 0      VOHC-001 2021-09-14   0.25  2f485e17-27ac-4337-ad04-d63a9fc578ad
# 1    NYSCHL-001 2021-09-14   0.90  c549ccac-ad50-4f41-a1d1-771745ee97e5
# 16    LCASE-001 2021-09-20   0.10  654e1b59-9979-403d-af50-35434a440e1b
# 17    LCASE-002 2021-09-20   0.15  4dd57553-dd3c-4308-a284-9b319c5cce60
# 18     FLUV-001 2021-09-20   0.10  aa34fbc6-7514-484d-af16-888fd70e949c
# 19  RAINNYC-009 2021-09-20   0.10  1459b052-de7f-4336-aacf-081bba01c54b
# 20     CASE-043 2021-09-20   0.01  b18273c3-1dab-4dcc-aa55-96caf7ba42e6
# 21    NHIGH-047 2021-09-20   0.55  bf6e42be-352a-4697-9ffb-be4371dd3ef5
#
#                                                 title             category  \
# 0   Will the CDC identify a variant of high conseq...             COVID-19
# 1   Will New York public schools remain fully open...             COVID-19
# 16  Will there be a day with at least 200,000 new ...             COVID-19
# 17  Will there be a day with at least 200,000 new ...             COVID-19
# 18  Will the FDA give emergency authorization for ...             COVID-19
# 19          Will it rain in New York City on Tuesday?  Climate and Weather
# 20  Will there be over 140,000 new COVID-19 cases ...             COVID-19
# 21  Will the high in New York City be over 76° on ...  Climate and Weather
#
#                                        tags  \
# 0                       [COVID-19, Variant]
# 1                     [New York, Education]
# 16               [COVID-19, Cases, Minimum]
# 17               [COVID-19, Cases, Minimum]
# 18                  [Covid-19, fluvoxamine]
# 19                                   [Rain]
# 20                           [COVID, Cases]
# 21  [Climate, Temperature, New York, Daily]
#
#                                     ranged_group_name  \
# 0       The CDC’s SARS-CoV-2 Variant Classifications.
# 1   The reopening plans of the New York City publi...
# 16  The reported number of new cases of COVID-19 p...
# 17  The reported number of new cases of COVID-19 p...
# 18    Press announcements issued by the FDA Newsroom.
# 19  The number of inches of precipitation recorded...
# 20  The number of new cases of COVID-19 published ...
# 21  The highest temperature recorded in Central Pa...
#
#                                             image_url min_tick_size  ...  \
# 0   https://kalshi-public-images.s3.us-east-2.amaz...         $0.01  ...
# 1   https://kalshi-public-images.s3.us-east-2.amaz...         $0.01  ...
# 16  https://kalshi-public-images.s3.us-east-2.amaz...         $0.01  ...
# 17  https://kalshi-public-images.s3.us-east-2.amaz...         $0.01  ...
# 18  https://kalshi-public-images.s3.us-east-2.amaz...         $0.01  ...
# 19  https://kalshi-public-images.s3.us-east-2.amaz...         $0.01  ...
# 20  https://kalshi-public-images.s3.us-east-2.amaz...         $0.01  ...
# 21  https://kalshi-public-images.s3.us-east-2.amaz...         $0.01  ...
#
#    yes_ask last_price previous_yes_bid previous_yes_ask previous_price  \
# 0     0.30       0.26             0.29             0.30           0.30
# 1     1.00       0.84             0.83             1.00           0.84
# 16    0.05       0.05             0.03             0.09           0.03
# 17    0.12       0.13             0.10             0.13           0.13
# 18    0.19       0.17             0.01             0.17           0.15
# 19    1.00       0.15             0.15             1.00           0.00
# 20    0.01       0.00             0.00             0.05           0.00
# 21    1.00       0.50             0.01             0.49           0.49
#
#     volume recent_volume open_interest result no_ask
# 0     2734           178          2392          0.80
# 1     5088             0          2896          1.00
# 16  132640          2990         22128          0.97
# 17     600           600           600          0.90
# 18    2650           472          1178          0.96
# 19     100           100           100          0.85
# 20       0             0             0          1.00
# 21     126           126           126          0.65
#
# [8 rows x 34 columns]

# %%
bets[['symbol', 'yes_bid', 'no_ask', 'yes_ask', 'last_price', 'myBet']]
# Out:
#          symbol  yes_bid  no_ask  yes_ask  last_price  myBet
# 0      VOHC-001     0.20    0.80     0.30        0.26   0.25
# 1    NYSCHL-001     0.00    1.00     1.00        0.84   0.90
# 16    LCASE-001     0.03    0.97     0.05        0.05   0.10
# 17    LCASE-002     0.10    0.90     0.12        0.13   0.15
# 18     FLUV-001     0.04    0.96     0.19        0.17   0.10
# 19  RAINNYC-009     0.15    0.85     1.00        0.15   0.10
# 20     CASE-043     0.00    1.00     0.01        0.00   0.01
# 21    NHIGH-047     0.35    0.65     1.00        0.50   0.55

# %%
bets['buyYes'] = bets.myBet >= bets.yes_ask
bets['buyNo'] = bets.myBet <= bets.yes_bid
bets['buyable'] = bets.buyYes | bets.buyNo

# %%
bets[['symbol', 'yes_bid', 'no_ask', 'yes_ask', 'last_price', 'myBet', 'buyYes', 'buyNo', 'buyable']]
# Out:
#          symbol  yes_bid  no_ask  yes_ask  last_price  myBet  buyYes  buyNo  \
# 0      VOHC-001     0.20    0.80     0.30        0.26   0.25   False  False
# 1    NYSCHL-001     0.00    1.00     1.00        0.84   0.90   False  False
# 16    LCASE-001     0.03    0.97     0.05        0.05   0.10    True  False
# 17    LCASE-002     0.10    0.90     0.12        0.13   0.15    True  False
# 18     FLUV-001     0.04    0.96     0.19        0.17   0.10   False  False
# 19  RAINNYC-009     0.15    0.85     1.00        0.15   0.10   False   True
# 20     CASE-043     0.00    1.00     0.01        0.00   0.01    True  False
# 21    NHIGH-047     0.35    0.65     1.00        0.50   0.55   False  False
#
#     buyable
# 0     False
# 1     False
# 16     True
# 17     True
# 18    False
# 19     True
# 20     True
# 21    False

# %%
bets = bets[bets.buyable]
bets['myp'] = bets.myBet.where(bets.buyYes, 1 - bets.myBet)  
bets['mktp'] = bets.yes_ask.where(bets.buyYes, 1 - bets.yes_bid)
bets[["mktq", "myq"]] = 1 - bets[["mktp", "myp"]]
bets["expected_value"] = (bets.myp * bets.mktq) - (
    bets.myq * bets.mktp
)
# Out:
# /tmp/ipykernel_5622/2935630589.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bets['myp'] = bets.myBet.where(bets.buyYes, 1 - bets.myBet)
# /tmp/ipykernel_5622/2935630589.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bets['mktp'] = bets.yes_ask.where(bets.buyYes, 1 - bets.yes_bid)
# /home/zack/miniconda3/envs/preds/lib/python3.9/site-packages/pandas/core/frame.py:3636: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /tmp/ipykernel_5622/2935630589.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bets["expected_value"] = (bets.myp * bets.mktq) - (

# %%
bets[['symbol', 'yes_bid', 'no_ask', 'yes_ask', 'last_price', 'myBet', 'buyYes', 'buyNo', 'buyable', 'expected_value']]
# Out:
#          symbol  yes_bid  no_ask  yes_ask  last_price  myBet  buyYes  buyNo  \
# 16    LCASE-001     0.03    0.97     0.05        0.05   0.10    True  False
# 17    LCASE-002     0.10    0.90     0.12        0.13   0.15    True  False
# 19  RAINNYC-009     0.15    0.85     1.00        0.15   0.10   False   True
# 20     CASE-043     0.00    1.00     0.01        0.00   0.01    True  False
#
#     buyable  expected_value
# 16     True            0.05
# 17     True            0.03
# 19     True            0.05
# 20     True            0.00

# %%
# todo: check order book?
